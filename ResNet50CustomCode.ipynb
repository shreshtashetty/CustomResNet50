# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications import ResNet50

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
model1 = ResNet50(
    include_top=True, weights='imagenet', input_tensor=None,
    input_shape=None, pooling=None, classes=1000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102973440/102967424 [==============================] - 1s 0us/step

# %%
import json
from pprint import pprint
json_string = model1.to_json()
json_object = json.loads(json_string)
pprint(json_object)
# Out:
# {'backend': 'tensorflow',
#  'class_name': 'Functional',
#  'config': {'input_layers': [['input_1', 0, 0]],
#             'layers': [{'class_name': 'InputLayer',
#                         'config': {'batch_input_shape': [None, 224, 224, 3],
#                                    'dtype': 'float32',
#                                    'name': 'input_1',
#                                    'ragged': False,
#                                    'sparse': False},
#                         'inbound_nodes': [],
#                         'name': 'input_1'},
#                        {'class_name': 'ZeroPadding2D',
#                         'config': {'data_format': 'channels_last',
#                                    'dtype': 'float32',
#                                    'name': 'conv1_pad',
#                                    'padding': [[3, 3], [3, 3]],
#                                    'trainable': True},
#                         'inbound_nodes': [[['input_1', 0, 0, {}]]],
#                         'name': 'conv1_pad'},
#                        {'class_name': 'Conv2D',
#                         'config': {'activation': 'linear',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'data_format': 'channels_last',
#                                    'dilation_rate': [1, 1],
#                                    'dtype': 'float32',
#                                    'filters': 64,
#                                    'groups': 1,
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                           'config': {'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'kernel_size': [7, 7],
#                                    'name': 'conv1_conv',
#                                    'padding': 'valid',
#                                    'strides': [2, 2],
#                                    'trainable': True,
#                                    'use_bias': True},
#                         'inbound_nodes': [[['conv1_pad', 0, 0, {}]]],
#                         'name': 'conv1_conv'},
#                        {'class_name': 'BatchNormalization',
#                         'config': {'axis': [3],
#                                    'beta_constraint': None,
#                                    'beta_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'beta_regularizer': None,
#                                    'center': True,
#                                    'dtype': 'float32',
#                                    'epsilon': 1.001e-05,
#                                    'gamma_constraint': None,
#                                    'gamma_initializer': {'class_name': 'Ones',
#                                                          'config': {}},
#                                    'gamma_regularizer': None,
#                                    'momentum': 0.99,
#                                    'moving_mean_initializer': {'class_name': 'Zeros',
#                                                                'config': {}},
#                                    'moving_variance_initializer': {'class_name': 'Ones',
#                                                                    'config': {}},
#                                    'name': 'conv1_bn',
#                                    'scale': True,
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv1_conv', 0, 0, {}]]],
#                         'name': 'conv1_bn'},
#                        {'class_name': 'Activation',
#                         'config': {'activation': 'relu',
#                                    'dtype': 'float32',
#                                    'name': 'conv1_relu',
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv1_bn', 0, 0, {}]]],
#                         'name': 'conv1_relu'},
#                        {'class_name': 'ZeroPadding2D',
#                         'config': {'data_format': 'channels_last',
#                                    'dtype': 'float32',
#                                    'name': 'pool1_pad',
#                                    'padding': [[1, 1], [1, 1]],
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv1_relu', 0, 0, {}]]],
#                         'name': 'pool1_pad'},
#                        {'class_name': 'MaxPooling2D',
#                         'config': {'data_format': 'channels_last',
#                                    'dtype': 'float32',
#                                    'name': 'pool1_pool',
#                                    'padding': 'valid',
#                                    'pool_size': [3, 3],
#                                    'strides': [2, 2],
#                                    'trainable': True},
#                         'inbound_nodes': [[['pool1_pad', 0, 0, {}]]],
#                         'name': 'pool1_pool'},
#                        {'class_name': 'Conv2D',
#                         'config': {'activation': 'linear',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'data_format': 'channels_last',
#                                    'dilation_rate': [1, 1],
#                                    'dtype': 'float32',
#                                    'filters': 64,
#                                    'groups': 1,
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                           'config': {'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'kernel_size': [1, 1],
#                                    'name': 'conv2_block1_1_conv',
#                                    'padding': 'valid',
#                                    'strides': [1, 1],
#                                    'trainable': True,
#                                    'use_bias': True},
#                         'inbound_nodes': [[['pool1_pool', 0, 0, {}]]],
#                         'name': 'conv2_block1_1_conv'},
#                        {'class_name': 'BatchNormalization',
#                         'config': {'axis': [3],
#                                    'beta_constraint': None,
#                                    'beta_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'beta_regularizer': None,
#                                    'center': True,
#                                    'dtype': 'float32',
#                                    'epsilon': 1.001e-05,
#                                    'gamma_constraint': None,
#                                    'gamma_initializer': {'class_name': 'Ones',
#                                                          'config': {}},
#                                    'gamma_regularizer': None,
#                                    'momentum': 0.99,
#                                    'moving_mean_initializer': {'class_name': 'Zeros',
#                                                                'config': {}},
#                                    'moving_variance_initializer': {'class_name': 'Ones',
#                                                                    'config': {}},
#                                    'name': 'conv2_block1_1_bn',
#                                    'scale': True,
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv2_block1_1_conv', 0, 0, {}]]],
#                         'name': 'conv2_block1_1_bn'},
#                        {'class_name': 'Activation',
#                         'config': {'activation': 'relu',
#                                    'dtype': 'float32',
#                                    'name': 'conv2_block1_1_relu',
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv2_block1_1_bn', 0, 0, {}]]],
#                         'name': 'conv2_block1_1_relu'},
#                        {'class_name': 'Conv2D',
#                         'config': {'activation': 'linear',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'data_format': 'channels_last',
#                                    'dilation_rate': [1, 1],
#                                    'dtype': 'float32',
#                                    'filters': 64,
#                                    'groups': 1,
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                           'config': {'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'kernel_size': [3, 3],
#                                    'name': 'conv2_block1_2_conv',
#                                    'padding': 'same',
#                                    'strides': [1, 1],
#                                    'trainable': True,
#                                    'use_bias': True},
#                         'inbound_nodes': [[['conv2_block1_1_relu', 0, 0, {}]]],
#                         'name': 'conv2_block1_2_conv'},
#                        {'class_name': 'BatchNormalization',
#                         'config': {'axis': [3],
#                                    'beta_constraint': None,
#                                    'beta_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'beta_regularizer': None,
#                                    'center': True,
#                                    'dtype': 'float32',
#                                    'epsilon': 1.001e-05,
#                                    'gamma_constraint': None,
#                                    'gamma_initializer': {'class_name': 'Ones',
#                                                          'config': {}},
#                                    'gamma_regularizer': None,
#                                    'momentum': 0.99,
#                                    'moving_mean_initializer': {'class_name': 'Zeros',
#                                                                'config': {}},
#                                    'moving_variance_initializer': {'class_name': 'Ones',
#                                                                    'config': {}},
#                                    'name': 'conv2_block1_2_bn',
#                                    'scale': True,
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv2_block1_2_conv', 0, 0, {}]]],
#                         'name': 'conv2_block1_2_bn'},
#                        {'class_name': 'Activation',
#                         'config': {'activation': 'relu',
#                                    'dtype': 'float32',
#                                    'name': 'conv2_block1_2_relu',
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv2_block1_2_bn', 0, 0, {}]]],
#                         'name': 'conv2_block1_2_relu'},
#                        {'class_name': 'Conv2D',
#                         'config': {'activation': 'linear',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'data_format': 'channels_last',
#                                    'dilation_rate': [1, 1],
#                                    'dtype': 'float32',
#                                    'filters': 256,
#                                    'groups': 1,
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                           'config': {'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'kernel_size': [1, 1],
#                                    'name': 'conv2_block1_0_conv',
#                                    'padding': 'valid',
#                                    'strides': [1, 1],
#                                    'trainable': True,
#                                    'use_bias': True},
#                         'inbound_nodes': [[['pool1_pool', 0, 0, {}]]],
#                         'name': 'conv2_block1_0_conv'},
#                        {'class_name': 'Conv2D',
#                         'config': {'activation': 'linear',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'data_format': 'channels_last',
#                                    'dilation_rate': [1, 1],
#                                    'dtype': 'float32',
#                                    'filters': 256,
#                                    'groups': 1,
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                           'config': {'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'kernel_size': [1, 1],
#                                    'name': 'conv2_block1_3_conv',
#                                    'padding': 'valid',
#                                    'strides': [1, 1],
#                                    'trainable': True,
#                                    'use_bias': True},
#                         'inbound_nodes': [[['conv2_block1_2_relu', 0, 0, {}]]],
#                         'name': 'conv2_block1_3_conv'},
#                        {'class_name': 'BatchNormalization',
#                         'config': {'axis': [3],
#                                    'beta_constraint': None,
#                                    'beta_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'beta_regularizer': None,
#                                    'center': True,
#                                    'dtype': 'float32',
#                                    'epsilon': 1.001e-05,
#                                    'gamma_constraint': None,
#                                    'gamma_initializer': {'class_name': 'Ones',
#                                                          'config': {}},
#                                    'gamma_regularizer': None,
#                                    'momentum': 0.99,
#                                    'moving_mean_initializer': {'class_name': 'Zeros',
#                                                                'config': {}},
#                                    'moving_variance_initializer': {'class_name': 'Ones',
#                                                                    'config': {}},
#                                    'name': 'conv2_block1_0_bn',
#                                    'scale': True,
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv2_block1_0_conv', 0, 0, {}]]],
#                         'name': 'conv2_block1_0_bn'},
#                        {'class_name': 'BatchNormalization',
#                         'config': {'axis': [3],
#                                    'beta_constraint': None,
#                                    'beta_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'beta_regularizer': None,
#                                    'center': True,
#                                    'dtype': 'float32',
#                                    'epsilon': 1.001e-05,
#                                    'gamma_constraint': None,
#                                    'gamma_initializer': {'class_name': 'Ones',
#                                                          'config': {}},
#                                    'gamma_regularizer': None,
#                                    'momentum': 0.99,
#                                    'moving_mean_initializer': {'class_name': 'Zeros',
#                                                                'config': {}},
#                                    'moving_variance_initializer': {'class_name': 'Ones',
#                                                                    'config': {}},
#                                    'name': 'conv2_block1_3_bn',
#                                    'scale': True,
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv2_block1_3_conv', 0, 0, {}]]],
#                         'name': 'conv2_block1_3_bn'},
#                        {'class_name': 'Add',
#                         'config': {'dtype': 'float32',
#                                    'name': 'conv2_block1_add',
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv2_block1_0_bn', 0, 0, {}],
#                                            ['conv2_block1_3_bn', 0, 0, {}]]],
#                         'name': 'conv2_block1_add'},
#                        {'class_name': 'Activation',
#                         'config': {'activation': 'relu',
#                                    'dtype': 'float32',
#                                    'name': 'conv2_block1_out',
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv2_block1_add', 0, 0, {}]]],
#                         'name': 'conv2_block1_out'},
#                        {'class_name': 'Conv2D',
#                         'config': {'activation': 'linear',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'data_format': 'channels_last',
#                                    'dilation_rate': [1, 1],
#                                    'dtype': 'float32',
#                                    'filters': 64,
#                                    'groups': 1,
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                           'config': {'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'kernel_size': [1, 1],
#                                    'name': 'conv2_block2_1_conv',
#                                    'padding': 'valid',
#                                    'strides': [1, 1],
#                                    'trainable': True,
#                                    'use_bias': True},
#                         'inbound_nodes': [[['conv2_block1_out', 0, 0, {}]]],
#                         'name': 'conv2_block2_1_conv'},
#                        {'class_name': 'BatchNormalization',
#                         'config': {'axis': [3],
#                                    'beta_constraint': None,
#                                    'beta_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'beta_regularizer': None,
#                                    'center': True,
#                                    'dtype': 'float32',
#                                    'epsilon': 1.001e-05,
#                                    'gamma_constraint': None,
#                                    'gamma_initializer': {'class_name': 'Ones',
#                                                          'config': {}},
#                                    'gamma_regularizer': None,
#                                    'momentum': 0.99,
#                                    'moving_mean_initializer': {'class_name': 'Zeros',
#                                                                'config': {}},
#                                    'moving_variance_initializer': {'class_name': 'Ones',
#                                                                    'config': {}},
#                                    'name': 'conv2_block2_1_bn',
#                                    'scale': True,
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv2_block2_1_conv', 0, 0, {}]]],
#                         'name': 'conv2_block2_1_bn'},
#                        {'class_name': 'Activation',
#                         'config': {'activation': 'relu',
#                                    'dtype': 'float32',
#                                    'name': 'conv2_block2_1_relu',
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv2_block2_1_bn', 0, 0, {}]]],
#                         'name': 'conv2_block2_1_relu'},
#                        {'class_name': 'Conv2D',
#                         'config': {'activation': 'linear',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'data_format': 'channels_last',
#                                    'dilation_rate': [1, 1],
#                                    'dtype': 'float32',
#                                    'filters': 64,
#                                    'groups': 1,
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                           'config': {'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'kernel_size': [3, 3],
#                                    'name': 'conv2_block2_2_conv',
#                                    'padding': 'same',
#                                    'strides': [1, 1],
#                                    'trainable': True,
#                                    'use_bias': True},
#                         'inbound_nodes': [[['conv2_block2_1_relu', 0, 0, {}]]],
#                         'name': 'conv2_block2_2_conv'},
#                        {'class_name': 'BatchNormalization',
#                         'config': {'axis': [3],
#                                    'beta_constraint': None,
#                                    'beta_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'beta_regularizer': None,
#                                    'center': True,
#                                    'dtype': 'float32',
#                                    'epsilon': 1.001e-05,
#                                    'gamma_constraint': None,
#                                    'gamma_initializer': {'class_name': 'Ones',
#                                                          'config': {}},
#                                    'gamma_regularizer': None,
#                                    'momentum': 0.99,
#                                    'moving_mean_initializer': {'class_name': 'Zeros',
#                                                                'config': {}},
#                                    'moving_variance_initializer': {'class_name': 'Ones',
#                                                                    'config': {}},
#                                    'name': 'conv2_block2_2_bn',
#                                    'scale': True,
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv2_block2_2_conv', 0, 0, {}]]],
#                         'name': 'conv2_block2_2_bn'},
#                        {'class_name': 'Activation',
#                         'config': {'activation': 'relu',
#                                    'dtype': 'float32',
#                                    'name': 'conv2_block2_2_relu',
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv2_block2_2_bn', 0, 0, {}]]],
#                         'name': 'conv2_block2_2_relu'},
#                        {'class_name': 'Conv2D',
#                         'config': {'activation': 'linear',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'data_format': 'channels_last',
#                                    'dilation_rate': [1, 1],
#                                    'dtype': 'float32',
#                                    'filters': 256,
#                                    'groups': 1,
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                           'config': {'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'kernel_size': [1, 1],
#                                    'name': 'conv2_block2_3_conv',
#                                    'padding': 'valid',
#                                    'strides': [1, 1],
#                                    'trainable': True,
#                                    'use_bias': True},
#                         'inbound_nodes': [[['conv2_block2_2_relu', 0, 0, {}]]],
#                         'name': 'conv2_block2_3_conv'},
#                        {'class_name': 'BatchNormalization',
#                         'config': {'axis': [3],
#                                    'beta_constraint': None,
#                                    'beta_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'beta_regularizer': None,
#                                    'center': True,
#                                    'dtype': 'float32',
#                                    'epsilon': 1.001e-05,
#                                    'gamma_constraint': None,
#                                    'gamma_initializer': {'class_name': 'Ones',
#                                                          'config': {}},
#                                    'gamma_regularizer': None,
#                                    'momentum': 0.99,
#                                    'moving_mean_initializer': {'class_name': 'Zeros',
#                                                                'config': {}},
#                                    'moving_variance_initializer': {'class_name': 'Ones',
#                                                                    'config': {}},
#                                    'name': 'conv2_block2_3_bn',
#                                    'scale': True,
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv2_block2_3_conv', 0, 0, {}]]],
#                         'name': 'conv2_block2_3_bn'},
#                        {'class_name': 'Add',
#                         'config': {'dtype': 'float32',
#                                    'name': 'conv2_block2_add',
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv2_block1_out', 0, 0, {}],
#                                            ['conv2_block2_3_bn', 0, 0, {}]]],
#                         'name': 'conv2_block2_add'},
#                        {'class_name': 'Activation',
#                         'config': {'activation': 'relu',
#                                    'dtype': 'float32',
#                                    'name': 'conv2_block2_out',
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv2_block2_add', 0, 0, {}]]],
#                         'name': 'conv2_block2_out'},
#                        {'class_name': 'Conv2D',
#                         'config': {'activation': 'linear',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'data_format': 'channels_last',
#                                    'dilation_rate': [1, 1],
#                                    'dtype': 'float32',
#                                    'filters': 64,
#                                    'groups': 1,
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                           'config': {'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'kernel_size': [1, 1],
#                                    'name': 'conv2_block3_1_conv',
#                                    'padding': 'valid',
#                                    'strides': [1, 1],
#                                    'trainable': True,
#                                    'use_bias': True},
#                         'inbound_nodes': [[['conv2_block2_out', 0, 0, {}]]],
#                         'name': 'conv2_block3_1_conv'},
#                        {'class_name': 'BatchNormalization',
#                         'config': {'axis': [3],
#                                    'beta_constraint': None,
#                                    'beta_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'beta_regularizer': None,
#                                    'center': True,
#                                    'dtype': 'float32',
#                                    'epsilon': 1.001e-05,
#                                    'gamma_constraint': None,
#                                    'gamma_initializer': {'class_name': 'Ones',
#                                                          'config': {}},
#                                    'gamma_regularizer': None,
#                                    'momentum': 0.99,
#                                    'moving_mean_initializer': {'class_name': 'Zeros',
#                                                                'config': {}},
#                                    'moving_variance_initializer': {'class_name': 'Ones',
#                                                                    'config': {}},
#                                    'name': 'conv2_block3_1_bn',
#                                    'scale': True,
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv2_block3_1_conv', 0, 0, {}]]],
#                         'name': 'conv2_block3_1_bn'},
#                        {'class_name': 'Activation',
#                         'config': {'activation': 'relu',
#                                    'dtype': 'float32',
#                                    'name': 'conv2_block3_1_relu',
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv2_block3_1_bn', 0, 0, {}]]],
#                         'name': 'conv2_block3_1_relu'},
#                        {'class_name': 'Conv2D',
#                         'config': {'activation': 'linear',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'data_format': 'channels_last',
#                                    'dilation_rate': [1, 1],
#                                    'dtype': 'float32',
#                                    'filters': 64,
#                                    'groups': 1,
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                           'config': {'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'kernel_size': [3, 3],
#                                    'name': 'conv2_block3_2_conv',
#                                    'padding': 'same',
#                                    'strides': [1, 1],
#                                    'trainable': True,
#                                    'use_bias': True},
#                         'inbound_nodes': [[['conv2_block3_1_relu', 0, 0, {}]]],
#                         'name': 'conv2_block3_2_conv'},
#                        {'class_name': 'BatchNormalization',
#                         'config': {'axis': [3],
#                                    'beta_constraint': None,
#                                    'beta_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'beta_regularizer': None,
#                                    'center': True,
#                                    'dtype': 'float32',
#                                    'epsilon': 1.001e-05,
#                                    'gamma_constraint': None,
#                                    'gamma_initializer': {'class_name': 'Ones',
#                                                          'config': {}},
#                                    'gamma_regularizer': None,
#                                    'momentum': 0.99,
#                                    'moving_mean_initializer': {'class_name': 'Zeros',
#                                                                'config': {}},
#                                    'moving_variance_initializer': {'class_name': 'Ones',
#                                                                    'config': {}},
#                                    'name': 'conv2_block3_2_bn',
#                                    'scale': True,
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv2_block3_2_conv', 0, 0, {}]]],
#                         'name': 'conv2_block3_2_bn'},
#                        {'class_name': 'Activation',
#                         'config': {'activation': 'relu',
#                                    'dtype': 'float32',
#                                    'name': 'conv2_block3_2_relu',
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv2_block3_2_bn', 0, 0, {}]]],
#                         'name': 'conv2_block3_2_relu'},
#                        {'class_name': 'Conv2D',
#                         'config': {'activation': 'linear',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'data_format': 'channels_last',
#                                    'dilation_rate': [1, 1],
#                                    'dtype': 'float32',
#                                    'filters': 256,
#                                    'groups': 1,
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                           'config': {'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'kernel_size': [1, 1],
#                                    'name': 'conv2_block3_3_conv',
#                                    'padding': 'valid',
#                                    'strides': [1, 1],
#                                    'trainable': True,
#                                    'use_bias': True},
#                         'inbound_nodes': [[['conv2_block3_2_relu', 0, 0, {}]]],
#                         'name': 'conv2_block3_3_conv'},
#                        {'class_name': 'BatchNormalization',
#                         'config': {'axis': [3],
#                                    'beta_constraint': None,
#                                    'beta_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'beta_regularizer': None,
#                                    'center': True,
#                                    'dtype': 'float32',
#                                    'epsilon': 1.001e-05,
#                                    'gamma_constraint': None,
#                                    'gamma_initializer': {'class_name': 'Ones',
#                                                          'config': {}},
#                                    'gamma_regularizer': None,
#                                    'momentum': 0.99,
#                                    'moving_mean_initializer': {'class_name': 'Zeros',
#                                                                'config': {}},
#                                    'moving_variance_initializer': {'class_name': 'Ones',
#                                                                    'config': {}},
#                                    'name': 'conv2_block3_3_bn',
#                                    'scale': True,
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv2_block3_3_conv', 0, 0, {}]]],
#                         'name': 'conv2_block3_3_bn'},
#                        {'class_name': 'Add',
#                         'config': {'dtype': 'float32',
#                                    'name': 'conv2_block3_add',
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv2_block2_out', 0, 0, {}],
#                                            ['conv2_block3_3_bn', 0, 0, {}]]],
#                         'name': 'conv2_block3_add'},
#                        {'class_name': 'Activation',
#                         'config': {'activation': 'relu',
#                                    'dtype': 'float32',
#                                    'name': 'conv2_block3_out',
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv2_block3_add', 0, 0, {}]]],
#                         'name': 'conv2_block3_out'},
#                        {'class_name': 'Conv2D',
#                         'config': {'activation': 'linear',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'data_format': 'channels_last',
#                                    'dilation_rate': [1, 1],
#                                    'dtype': 'float32',
#                                    'filters': 128,
#                                    'groups': 1,
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                           'config': {'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'kernel_size': [1, 1],
#                                    'name': 'conv3_block1_1_conv',
#                                    'padding': 'valid',
#                                    'strides': [2, 2],
#                                    'trainable': True,
#                                    'use_bias': True},
#                         'inbound_nodes': [[['conv2_block3_out', 0, 0, {}]]],
#                         'name': 'conv3_block1_1_conv'},
#                        {'class_name': 'BatchNormalization',
#                         'config': {'axis': [3],
#                                    'beta_constraint': None,
#                                    'beta_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'beta_regularizer': None,
#                                    'center': True,
#                                    'dtype': 'float32',
#                                    'epsilon': 1.001e-05,
#                                    'gamma_constraint': None,
#                                    'gamma_initializer': {'class_name': 'Ones',
#                                                          'config': {}},
#                                    'gamma_regularizer': None,
#                                    'momentum': 0.99,
#                                    'moving_mean_initializer': {'class_name': 'Zeros',
#                                                                'config': {}},
#                                    'moving_variance_initializer': {'class_name': 'Ones',
#                                                                    'config': {}},
#                                    'name': 'conv3_block1_1_bn',
#                                    'scale': True,
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv3_block1_1_conv', 0, 0, {}]]],
#                         'name': 'conv3_block1_1_bn'},
#                        {'class_name': 'Activation',
#                         'config': {'activation': 'relu',
#                                    'dtype': 'float32',
#                                    'name': 'conv3_block1_1_relu',
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv3_block1_1_bn', 0, 0, {}]]],
#                         'name': 'conv3_block1_1_relu'},
#                        {'class_name': 'Conv2D',
#                         'config': {'activation': 'linear',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'data_format': 'channels_last',
#                                    'dilation_rate': [1, 1],
#                                    'dtype': 'float32',
#                                    'filters': 128,
#                                    'groups': 1,
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                           'config': {'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'kernel_size': [3, 3],
#                                    'name': 'conv3_block1_2_conv',
#                                    'padding': 'same',
#                                    'strides': [1, 1],
#                                    'trainable': True,
#                                    'use_bias': True},
#                         'inbound_nodes': [[['conv3_block1_1_relu', 0, 0, {}]]],
#                         'name': 'conv3_block1_2_conv'},
#                        {'class_name': 'BatchNormalization',
#                         'config': {'axis': [3],
#                                    'beta_constraint': None,
#                                    'beta_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'beta_regularizer': None,
#                                    'center': True,
#                                    'dtype': 'float32',
#                                    'epsilon': 1.001e-05,
#                                    'gamma_constraint': None,
#                                    'gamma_initializer': {'class_name': 'Ones',
#                                                          'config': {}},
#                                    'gamma_regularizer': None,
#                                    'momentum': 0.99,
#                                    'moving_mean_initializer': {'class_name': 'Zeros',
#                                                                'config': {}},
#                                    'moving_variance_initializer': {'class_name': 'Ones',
#                                                                    'config': {}},
#                                    'name': 'conv3_block1_2_bn',
#                                    'scale': True,
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv3_block1_2_conv', 0, 0, {}]]],
#                         'name': 'conv3_block1_2_bn'},
#                        {'class_name': 'Activation',
#                         'config': {'activation': 'relu',
#                                    'dtype': 'float32',
#                                    'name': 'conv3_block1_2_relu',
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv3_block1_2_bn', 0, 0, {}]]],
#                         'name': 'conv3_block1_2_relu'},
#                        {'class_name': 'Conv2D',
#                         'config': {'activation': 'linear',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'data_format': 'channels_last',
#                                    'dilation_rate': [1, 1],
#                                    'dtype': 'float32',
#                                    'filters': 512,
# ...
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'data_format': 'channels_last',
#                                    'dilation_rate': [1, 1],
#                                    'dtype': 'float32',
#                                    'filters': 2048,
#                                    'groups': 1,
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                           'config': {'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'kernel_size': [1, 1],
#                                    'name': 'conv5_block2_3_conv',
#                                    'padding': 'valid',
#                                    'strides': [1, 1],
#                                    'trainable': True,
#                                    'use_bias': True},
#                         'inbound_nodes': [[['conv5_block2_2_relu', 0, 0, {}]]],
#                         'name': 'conv5_block2_3_conv'},
#                        {'class_name': 'BatchNormalization',
#                         'config': {'axis': [3],
#                                    'beta_constraint': None,
#                                    'beta_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'beta_regularizer': None,
#                                    'center': True,
#                                    'dtype': 'float32',
#                                    'epsilon': 1.001e-05,
#                                    'gamma_constraint': None,
#                                    'gamma_initializer': {'class_name': 'Ones',
#                                                          'config': {}},
#                                    'gamma_regularizer': None,
#                                    'momentum': 0.99,
#                                    'moving_mean_initializer': {'class_name': 'Zeros',
#                                                                'config': {}},
#                                    'moving_variance_initializer': {'class_name': 'Ones',
#                                                                    'config': {}},
#                                    'name': 'conv5_block2_3_bn',
#                                    'scale': True,
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv5_block2_3_conv', 0, 0, {}]]],
#                         'name': 'conv5_block2_3_bn'},
#                        {'class_name': 'Add',
#                         'config': {'dtype': 'float32',
#                                    'name': 'conv5_block2_add',
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv5_block1_out', 0, 0, {}],
#                                            ['conv5_block2_3_bn', 0, 0, {}]]],
#                         'name': 'conv5_block2_add'},
#                        {'class_name': 'Activation',
#                         'config': {'activation': 'relu',
#                                    'dtype': 'float32',
#                                    'name': 'conv5_block2_out',
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv5_block2_add', 0, 0, {}]]],
#                         'name': 'conv5_block2_out'},
#                        {'class_name': 'Conv2D',
#                         'config': {'activation': 'linear',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'data_format': 'channels_last',
#                                    'dilation_rate': [1, 1],
#                                    'dtype': 'float32',
#                                    'filters': 512,
#                                    'groups': 1,
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                           'config': {'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'kernel_size': [1, 1],
#                                    'name': 'conv5_block3_1_conv',
#                                    'padding': 'valid',
#                                    'strides': [1, 1],
#                                    'trainable': True,
#                                    'use_bias': True},
#                         'inbound_nodes': [[['conv5_block2_out', 0, 0, {}]]],
#                         'name': 'conv5_block3_1_conv'},
#                        {'class_name': 'BatchNormalization',
#                         'config': {'axis': [3],
#                                    'beta_constraint': None,
#                                    'beta_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'beta_regularizer': None,
#                                    'center': True,
#                                    'dtype': 'float32',
#                                    'epsilon': 1.001e-05,
#                                    'gamma_constraint': None,
#                                    'gamma_initializer': {'class_name': 'Ones',
#                                                          'config': {}},
#                                    'gamma_regularizer': None,
#                                    'momentum': 0.99,
#                                    'moving_mean_initializer': {'class_name': 'Zeros',
#                                                                'config': {}},
#                                    'moving_variance_initializer': {'class_name': 'Ones',
#                                                                    'config': {}},
#                                    'name': 'conv5_block3_1_bn',
#                                    'scale': True,
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv5_block3_1_conv', 0, 0, {}]]],
#                         'name': 'conv5_block3_1_bn'},
#                        {'class_name': 'Activation',
#                         'config': {'activation': 'relu',
#                                    'dtype': 'float32',
#                                    'name': 'conv5_block3_1_relu',
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv5_block3_1_bn', 0, 0, {}]]],
#                         'name': 'conv5_block3_1_relu'},
#                        {'class_name': 'Conv2D',
#                         'config': {'activation': 'linear',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'data_format': 'channels_last',
#                                    'dilation_rate': [1, 1],
#                                    'dtype': 'float32',
#                                    'filters': 512,
#                                    'groups': 1,
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                           'config': {'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'kernel_size': [3, 3],
#                                    'name': 'conv5_block3_2_conv',
#                                    'padding': 'same',
#                                    'strides': [1, 1],
#                                    'trainable': True,
#                                    'use_bias': True},
#                         'inbound_nodes': [[['conv5_block3_1_relu', 0, 0, {}]]],
#                         'name': 'conv5_block3_2_conv'},
#                        {'class_name': 'BatchNormalization',
#                         'config': {'axis': [3],
#                                    'beta_constraint': None,
#                                    'beta_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'beta_regularizer': None,
#                                    'center': True,
#                                    'dtype': 'float32',
#                                    'epsilon': 1.001e-05,
#                                    'gamma_constraint': None,
#                                    'gamma_initializer': {'class_name': 'Ones',
#                                                          'config': {}},
#                                    'gamma_regularizer': None,
#                                    'momentum': 0.99,
#                                    'moving_mean_initializer': {'class_name': 'Zeros',
#                                                                'config': {}},
#                                    'moving_variance_initializer': {'class_name': 'Ones',
#                                                                    'config': {}},
#                                    'name': 'conv5_block3_2_bn',
#                                    'scale': True,
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv5_block3_2_conv', 0, 0, {}]]],
#                         'name': 'conv5_block3_2_bn'},
#                        {'class_name': 'Activation',
#                         'config': {'activation': 'relu',
#                                    'dtype': 'float32',
#                                    'name': 'conv5_block3_2_relu',
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv5_block3_2_bn', 0, 0, {}]]],
#                         'name': 'conv5_block3_2_relu'},
#                        {'class_name': 'Conv2D',
#                         'config': {'activation': 'linear',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'data_format': 'channels_last',
#                                    'dilation_rate': [1, 1],
#                                    'dtype': 'float32',
#                                    'filters': 2048,
#                                    'groups': 1,
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                           'config': {'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'kernel_size': [1, 1],
#                                    'name': 'conv5_block3_3_conv',
#                                    'padding': 'valid',
#                                    'strides': [1, 1],
#                                    'trainable': True,
#                                    'use_bias': True},
#                         'inbound_nodes': [[['conv5_block3_2_relu', 0, 0, {}]]],
#                         'name': 'conv5_block3_3_conv'},
#                        {'class_name': 'BatchNormalization',
#                         'config': {'axis': [3],
#                                    'beta_constraint': None,
#                                    'beta_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'beta_regularizer': None,
#                                    'center': True,
#                                    'dtype': 'float32',
#                                    'epsilon': 1.001e-05,
#                                    'gamma_constraint': None,
#                                    'gamma_initializer': {'class_name': 'Ones',
#                                                          'config': {}},
#                                    'gamma_regularizer': None,
#                                    'momentum': 0.99,
#                                    'moving_mean_initializer': {'class_name': 'Zeros',
#                                                                'config': {}},
#                                    'moving_variance_initializer': {'class_name': 'Ones',
#                                                                    'config': {}},
#                                    'name': 'conv5_block3_3_bn',
#                                    'scale': True,
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv5_block3_3_conv', 0, 0, {}]]],
#                         'name': 'conv5_block3_3_bn'},
#                        {'class_name': 'Add',
#                         'config': {'dtype': 'float32',
#                                    'name': 'conv5_block3_add',
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv5_block2_out', 0, 0, {}],
#                                            ['conv5_block3_3_bn', 0, 0, {}]]],
#                         'name': 'conv5_block3_add'},
#                        {'class_name': 'Activation',
#                         'config': {'activation': 'relu',
#                                    'dtype': 'float32',
#                                    'name': 'conv5_block3_out',
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv5_block3_add', 0, 0, {}]]],
#                         'name': 'conv5_block3_out'},
#                        {'class_name': 'GlobalAveragePooling2D',
#                         'config': {'data_format': 'channels_last',
#                                    'dtype': 'float32',
#                                    'name': 'avg_pool',
#                                    'trainable': True},
#                         'inbound_nodes': [[['conv5_block3_out', 0, 0, {}]]],
#                         'name': 'avg_pool'},
#                        {'class_name': 'Dense',
#                         'config': {'activation': 'softmax',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'dtype': 'float32',
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                           'config': {'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'name': 'predictions',
#                                    'trainable': True,
#                                    'units': 1000,
#                                    'use_bias': True},
#                         'inbound_nodes': [[['avg_pool', 0, 0, {}]]],
#                         'name': 'predictions'}],
#             'name': 'resnet50',
#             'output_layers': [['predictions', 0, 0]]},
#  'keras_version': '2.4.0'}

# %%
class ResidualBlock(keras.layers.Layer):
  def __init__(self, filters, kernel_size, stride, **kwargs):
    super().__init__(**kwargs)
    self.filter1, self.filter2, self.filter3 = tf.unstack(filters, axis=-1)
    ks1, ks2, ks3 = tf.unstack(kernel_size, axis=-1)
    s1, s2, s3 = tf.unstack(stride, axis=-1)
    self.conv1 = keras.layers.Conv2D(self.filter1,int(ks1),strides=int(s1),padding='same',activation='relu') #Gave me an error for just writing s1 instead
    self.bn1 = keras.layers.BatchNormalization()                                                           #of (s1, s1). Though I have seen cases that 
    self.conv2 = keras.layers.Conv2D(self.filter2,(ks2,ks2),strides=(s2, s2),padding='same',activation='relu') #do the former. Why? s1 and ks1 are tensors 
    self.bn2 = keras.layers.BatchNormalization()                                                             #with shape info. for individual vals passed tensor shape is 0.
    self.conv3 = keras.layers.Conv2D(self.filter3,(ks3,ks3),strides=(s3, s3),padding='same',activation=None) #which is wrong.
    self.bn3 = keras.layers.BatchNormalization()

    self.skip_layer = [] #the extra convolution + bn for the input layer when stride size = 2
    if(s1>1):
      self.skip_layer.append(keras.layers.Conv2D(self.filter3, (1,1),strides=(s1, s1),padding='same'))
      # print("FOR STRIDE=2")
    else:
      self.skip_layer.append(keras.layers.Conv2D(self.filter3, (1,1),strides=(1, 1),padding='same'))
    self.skip_layer.append(keras.layers.BatchNormalization())
    self.activ = keras.layers.Activation("relu")

  def call(self, x):
    z = x
    skip_z = x
    z = self.conv1(z)
    z = self.bn1(z)
    z = self.conv2(z)
    z = self.bn2(z)
    z = self.conv3(z)
    z = self.bn3(z)
    for layer in self.skip_layer:
      # print("SKIP LAYER")
      skip_z = layer(skip_z)
    z = self.activ(z + skip_z)
    # print(z.shape)
    return z

# %%
class ResNet50Model(keras.models.Model): #in the textbook, they have imported keras.Model. for layers they import keras.layers.Layer
  def __init__(self, **kwargs):
    super().__init__(**kwargs)
    self.conv1 = keras.layers.Conv2D(64, kernel_size=(7, 7), strides=(2, 2), padding="same", input_shape=(224, 224, 3), activation='relu')
    self.bn1 = keras.layers.BatchNormalization()
    self.maxpool = keras.layers.MaxPool2D(pool_size=(3, 3), strides=(2, 2), padding='same')

    self.stage1_1 = ResidualBlock([64, 64, 256], [1, 3, 1], [1, 1, 1]) # x3 times
    self.bn1_1 = keras.layers.BatchNormalization()
    self.stage1_2 = ResidualBlock([64, 64, 256], [1, 3, 1], [1, 1, 1])
    self.bn1_2 = keras.layers.BatchNormalization()
    self.stage1_3 = ResidualBlock([64, 64, 256], [1, 3, 1], [1, 1, 1])
    self.bn1_3 = keras.layers.BatchNormalization()

    self.stage2_1 = ResidualBlock([128, 128, 512], [1, 3, 1], [2, 1, 1]) #once with s1 = 2, 3 mores times with s1 = 1
    self.bn2_1 = keras.layers.BatchNormalization()
    self.stage2_2 = ResidualBlock([128, 128, 512], [1, 3, 1], [1, 1, 1])
    self.bn2_2 = keras.layers.BatchNormalization()
    self.stage2_3 = ResidualBlock([128, 128, 512], [1, 3, 1], [1, 1, 1])
    self.bn2_3 = keras.layers.BatchNormalization()
    self.stage2_4 = ResidualBlock([128, 128, 512], [1, 3, 1], [1, 1, 1])
    self.bn2_4 = keras.layers.BatchNormalization()

    self.stage3_1 = ResidualBlock([256, 256, 1024], [1, 3, 1], [2, 1, 1]) #once with s1 = 2, 5 mores times with s1 = 1
    self.bn3_1 = keras.layers.BatchNormalization()
    self.stage3_2 = ResidualBlock([256, 256, 1024], [1, 3, 1], [1, 1, 1])
    self.bn3_2 = keras.layers.BatchNormalization()
    self.stage3_3 = ResidualBlock([256, 256, 1024], [1, 3, 1], [1, 1, 1])
    self.bn3_3 = keras.layers.BatchNormalization()
    self.stage3_4 = ResidualBlock([256, 256, 1024], [1, 3, 1], [1, 1, 1])
    self.bn3_4 = keras.layers.BatchNormalization()
    self.stage3_5 = ResidualBlock([256, 256, 1024], [1, 3, 1], [1, 1, 1])
    self.bn3_5 = keras.layers.BatchNormalization()
    self.stage3_6 = ResidualBlock([256, 256, 1024], [1, 3, 1], [1, 1, 1])
    self.bn3_6 = keras.layers.BatchNormalization()

    self.stage4_1 = ResidualBlock([512, 512, 2048], [1, 3, 1], [2, 1, 1]) # x3 times
    self.bn4_1 = keras.layers.BatchNormalization()
    self.stage4_2 = ResidualBlock([512, 512, 2048], [1, 3, 1], [1, 1, 1])
    self.bn4_2 = keras.layers.BatchNormalization()
    self.stage4_3 = ResidualBlock([512, 512, 2048], [1, 3, 1], [1, 1, 1])
    self.bn4_3 = keras.layers.BatchNormalization()

    self.globalavgpool = keras.layers.GlobalAveragePooling2D()
    self.flatten = keras.layers.Flatten()
    self.dense = keras.layers.Dense(10, activation='softmax')

  def call(self, x):
    Z = self.conv1(x)
    Z = self.bn1(Z)
    Z = self.maxpool(Z)

    Z = self.stage1_1(Z)
    Z = self.bn1_1(Z)
    Z = self.stage1_2(Z)
    Z = self.bn1_2(Z)
    Z = self.stage1_3(Z)
    Z = self.bn1_3(Z)

    Z = self.stage2_1(Z)
    Z = self.bn2_1(Z)
    Z = self.stage2_2(Z)
    Z = self.bn2_2(Z)
    Z = self.stage2_3(Z)
    Z = self.bn2_3(Z)
    Z = self.stage2_4(Z)
    Z = self.bn2_4(Z)

    Z = self.stage3_1(Z)
    Z = self.bn3_1(Z)
    Z = self.stage3_2(Z)
    Z = self.bn3_2(Z)
    Z = self.stage3_3(Z)
    Z = self.bn3_3(Z)
    Z = self.stage3_4(Z)
    Z = self.bn3_4(Z)
    Z = self.stage3_5(Z)
    Z = self.bn3_5(Z)
    Z = self.stage3_6(Z)
    Z = self.bn3_6(Z)

    Z = self.stage4_1(Z)
    Z = self.bn4_1(Z)
    Z = self.stage4_2(Z)
    Z = self.bn4_2(Z)
    Z = self.stage4_3(Z)
    Z = self.bn4_3(Z)

    Z = self.globalavgpool(Z)
    Z = self.flatten(Z)
    Z = self.dense(Z)
    return Z

# %%
model = ResNet50Model()

# %%
model.build((1, 224, 224, 3))

# %%
model.summary()
# Out:
# Model: "res_net50model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              multiple                  9472
# _________________________________________________________________
# batch_normalization (BatchNo multiple                  256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) multiple                  0
# _________________________________________________________________
# residual_block (ResidualBloc multiple                  76928
# _________________________________________________________________
# batch_normalization_5 (Batch multiple                  1024
# _________________________________________________________________
# residual_block_1 (ResidualBl multiple                  138368
# _________________________________________________________________
# batch_normalization_10 (Batc multiple                  1024
# _________________________________________________________________
# residual_block_2 (ResidualBl multiple                  138368
# _________________________________________________________________
# batch_normalization_15 (Batc multiple                  1024
# _________________________________________________________________
# residual_block_3 (ResidualBl multiple                  383232
# _________________________________________________________________
# batch_normalization_20 (Batc multiple                  2048
# _________________________________________________________________
# residual_block_4 (ResidualBl multiple                  547072
# _________________________________________________________________
# batch_normalization_25 (Batc multiple                  2048
# _________________________________________________________________
# residual_block_5 (ResidualBl multiple                  547072
# _________________________________________________________________
# batch_normalization_30 (Batc multiple                  2048
# _________________________________________________________________
# residual_block_6 (ResidualBl multiple                  547072
# _________________________________________________________________
# batch_normalization_35 (Batc multiple                  2048
# _________________________________________________________________
# residual_block_7 (ResidualBl multiple                  1520128
# _________________________________________________________________
# batch_normalization_40 (Batc multiple                  4096
# _________________________________________________________________
# residual_block_8 (ResidualBl multiple                  2175488
# _________________________________________________________________
# batch_normalization_45 (Batc multiple                  4096
# _________________________________________________________________
# residual_block_9 (ResidualBl multiple                  2175488
# _________________________________________________________________
# batch_normalization_50 (Batc multiple                  4096
# _________________________________________________________________
# residual_block_10 (ResidualB multiple                  2175488
# _________________________________________________________________
# batch_normalization_55 (Batc multiple                  4096
# _________________________________________________________________
# residual_block_11 (ResidualB multiple                  2175488
# _________________________________________________________________
# batch_normalization_60 (Batc multiple                  4096
# _________________________________________________________________
# residual_block_12 (ResidualB multiple                  2175488
# _________________________________________________________________
# batch_normalization_65 (Batc multiple                  4096
# _________________________________________________________________
# residual_block_13 (ResidualB multiple                  6054912
# _________________________________________________________________
# batch_normalization_70 (Batc multiple                  8192
# _________________________________________________________________
# residual_block_14 (ResidualB multiple                  8676352
# _________________________________________________________________
# batch_normalization_75 (Batc multiple                  8192
# _________________________________________________________________
# residual_block_15 (ResidualB multiple                  8676352
# _________________________________________________________________
# batch_normalization_80 (Batc multiple                  8192
# _________________________________________________________________
# global_average_pooling2d (Gl multiple                  0
# _________________________________________________________________
# flatten (Flatten)            multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  2049000
# =================================================================
# Total params: 40,302,440
# Trainable params: 40,196,584
# Non-trainable params: 105,856
# _________________________________________________________________

# %%
# def print_status_bar(iteration, total, loss, metrics=None):
#   metrics = " - ".join(["{}: {:.4f}".format(m.name, m.result()) for m in [loss] + (metrics or []) ])
#   end = "" if iteration<total else "\n"
#   print("\r{}/{} - ".format(iteration, total) + metrics, end=end)

# %%
n_epochs = 1
batch_size = 32
n_steps = len(x_train)/batch_size

# %%
x_train = x_train/255.0
x_test = x_test/255.0

# %%
x_train = x_train.astype('float32')
y_train = y_train.astype('int32')
x_test = x_test.astype('float32')
y_test = y_test.astype('int32')

# %%
train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

# %%
# train_ds = train_ds.map(lambda x, y: tf.cast(x, tf.float32), y)
# train_ds.take(1)

# %%
optimizer = keras.optimizers.Nadam(lr = 0.01)
loss_fn = keras.losses.SparseCategoricalCrossentropy()

# %%
metrics = keras.metrics.SparseCategoricalAccuracy() 
metric_test = keras.metrics.SparseCategoricalAccuracy()

# %%
for epoch in range(1, n_epochs+1):
  print("Epoch {}/{}".format(epoch, n_epochs))
  for step,(X_batch, y_batch) in enumerate(train_ds):
    # X_batch, y_batch = train_ds
    # with tf.GradientTape() as tape:
    #   y_pred = model(X_batch, training=True)
    #   loss = tf.reduce_mean(loss_fn(y_batch, y_pred))
    # gradients = tape.gradient(loss, model.trainable_variables)
    # optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    # metrics.update_state(y_batch, y_pred)
    loss = training_step(X_batch, y_batch)
    # print_status_bar(step*batch_size, len(y_train), loss, metrics)
    if(step%100==0):
      print('epoch: {} step: {} loss: {}  accuracy: {}'.format(epoch, step, loss, metrics.result()), end='\n')
  metrics.reset_states()
  for _step,(_X_batch, _y_batch) in enumerate(test_ds):
    _y_pred = model(_X_batch, training=False)
    loss = tf.reduce_mean(loss_fn(_y_batch, _y_pred))
    metric_test.update_state(y_batch, y_pred)
  print('epoch: {} step_val: {} loss_val: {}  accuracy_val: {}'.format(epoch, _step, loss, metric_test.result()), end='\n')
  metric_test.reset_states()
# Out:
# Epoch 1/1
# epoch: 1 step: 0 loss: 30.999771118164062  accuracy: 0.15625
# epoch: 1 step: 100 loss: 24.512500762939453  accuracy: 0.09158416092395782
# epoch: 1 step: 200 loss: 25.86250114440918  accuracy: 0.09375
# epoch: 1 step: 300 loss: 26.78750228881836  accuracy: 0.09385382384061813
# epoch: 1 step: 400 loss: 23.69998550415039  accuracy: 0.09445136785507202
# epoch: 1 step: 500 loss: 22.924999237060547  accuracy: 0.09406187385320663
# epoch: 1 step: 600 loss: 20.825000762939453  accuracy: 0.09463394433259964
# epoch: 1 step: 700 loss: 26.350000381469727  accuracy: 0.09539943188428879
# epoch: 1 step: 800 loss: 24.78750228881836  accuracy: 0.09531054645776749
# epoch: 1 step: 900 loss: 18.875  accuracy: 0.09558823704719543
# epoch: 1 step: 1000 loss: 22.299999237060547  accuracy: 0.09577921777963638
# epoch: 1 step: 1100 loss: 30.962501525878906  accuracy: 0.09576521068811417
# epoch: 1 step: 1200 loss: 38.05000305175781  accuracy: 0.09629996120929718
# epoch: 1 step: 1300 loss: 30.96165657043457  accuracy: 0.09646426141262054
# epoch: 1 step: 1400 loss: 28.512500762939453  accuracy: 0.09702891111373901
# epoch: 1 step: 1500 loss: 16.8125  accuracy: 0.09747668355703354
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-87-57e06c7f4382> in <module>()
#      17     _y_pred = model(_X_batch, training=False)
#      18     loss = tf.reduce_mean(loss_fn(_y_batch, _y_pred))
# ---> 19     metric_test.update_state(y_batch, y_pred)
#      20   print('epoch: {} step_val: {} loss_val: {}  accuracy_val: {}'.format(epoch, _step, loss, metric_test.result()), end='\n')
#      21   metric_test.reset_states()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/metrics_utils.py in decorated(metric_obj, *args, **kwargs)
#      88
#      89     with tf_utils.graph_context_for_symbolic_tensors(*args, **kwargs):
# ---> 90       update_op = update_state_fn(*args, **kwargs)
#      91     if update_op is not None:  # update_op will be None in eager execution.
#      92       metric_obj.add_update(update_op)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/metrics.py in update_state_fn(*args, **kwargs)
#     175         control_status = ag_ctx.control_status_ctx()
#     176         ag_update_state = autograph.tf_convert(obj_update_state, control_status)
# --> 177         return ag_update_state(*args, **kwargs)
#     178     else:
#     179       if isinstance(obj.update_state, def_function.Function):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     665       try:
#     666         with conversion_ctx:
# --> 667           return converted_call(f, args, kwargs, options=options)
#     668       except Exception as e:  # pylint:disable=broad-except
#     669         if hasattr(e, 'ag_error_metadata'):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     348   if conversion.is_in_allowlist_cache(f, options):
#     349     logging.log(2, 'Allowlisted %s: from cache', f)
# --> 350     return _call_unconverted(f, args, kwargs, options, False)
#     351
#     352   if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     476
#     477   if kwargs is not None:
# --> 478     return f(*args, **kwargs)
#     479   return f(*args)
#     480
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/metrics.py in update_state(self, y_true, y_pred, sample_weight)
#     616
#     617     ag_fn = autograph.tf_convert(self._fn, ag_ctx.control_status_ctx())
# --> 618     matches = ag_fn(y_true, y_pred, **self._fn_kwargs)
#     619     return super(MeanMetricWrapper, self).update_state(
#     620         matches, sample_weight=sample_weight)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/metrics.py in sparse_categorical_accuracy(y_true, y_pred)
#    3313     y_pred = math_ops.cast(y_pred, K.dtype(y_true))
#    3314
# -> 3315   return math_ops.cast(math_ops.equal(y_true, y_pred), K.floatx())
#    3316
#    3317
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py in equal(x, y, name)
#    1677     `tf.errors.InvalidArgumentError`: If shapes of arguments are incompatible
#    1678   """
# -> 1679   return gen_math_ops.equal(x, y, name=name)
#    1680
#    1681
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_math_ops.py in equal(x, y, incompatible_shape_error, name)
#    3162       return _result
#    3163     except _core._NotOkStatusException as e:
# -> 3164       _ops.raise_from_not_ok_status(e, name)
#    3165     except _core._FallbackException:
#    3166       pass
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6860   message = e.message + (" name: " + name if name is not None else "")
#    6861   # pylint: disable=protected-access
# -> 6862   six.raise_from(core._status_to_exception(e.code, message), None)
#    6863   # pylint: enable=protected-access
#    6864
#
# /usr/local/lib/python3.6/dist-packages/six.py in raise_from(value, from_value)
#
# InvalidArgumentError: Incompatible shapes: [16] vs. [32] [Op:Equal]

# %%
@tf.function
def training_step(x, y):
  with tf.GradientTape() as tape:
      y_pred = model(x, training=True)
      loss = tf.reduce_mean(loss_fn(y, y_pred))
  gradients = tape.gradient(loss, model.trainable_variables)
  optimizer.apply_gradients(zip(gradients, model.trainable_variables))
  metrics.update_state(y, y_pred)
  return loss

# %% [markdown]
# Training loop still in the works. Looking for ways to get the imagenet dataset, otherwise will have to use some other readily available dataset.

# %%
for epoch in range(1, n_epochs+1):
  print("Epoch {}/{}".format(epoch, n_epochs))
  for step in range(1, n_steps+1):
    # X_batch, y_batch = -------------TODO
    with tf.GradientTape() as tape:
      y_pred = model(X_batch, training=True)
      loss = tf.reduce_mean(loss_fn(y_batch, y_pred))
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    mean_loss(loss)
    for metric in metrics:
      metric(y_batch, y_pred)
    print_status_bar(step*batch_size, len(y_train), mean_loss, metrics)
  print_status_bar(len(y_train), len(y_train), mean_loss, metrics)
  for metric in [mean_loss] + metrics:
    metric.reset_states()

# %% [markdown]
# @tf.custom_gradient

# %%
@tf.custom_gradient
def log_of_exp(x):
  def grad(dy): 
    print(dy)# dy=gradients from previous terms as per chain rule
    return dy*(1-(1/(1+tf.exp(x))))
  return tf.math.log(1+tf.exp(x)), grad

# %%
def der_log_exp(x):
  return 1-(1/(1+tf.exp(x)))

# %%
x = tf.Variable(3.0)
with tf.GradientTape() as tape:
  # y = log_of_exp(x)
  y = (x**2)+3
  z = log_of_exp(y)
  z2 = z**2
grad = tape.gradient(z2, x)
print(grad)
# print(der_log_exp(x))
# Out:
# tf.Tensor(24.000011, shape=(), dtype=float32)
# tf.Tensor(143.99919, shape=(), dtype=float32)

# %%
log_of_exp(12.0)*2
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=24.000011>

# %%
x = tf.Variable(3.0, name='x')
x1 = tf.constant(4.0,name='x1')
x2 = tf.Variable(2.0, name='x2')
with tf.GradientTape() as tape:
  tape.watch(x1)
  y = (x**2)+ (3*x1) + tf.stop_gradient(x2**3)
  # z = log_of_exp(y)
  # z2 = z**2
grad = tape.gradient(y, [x, x1, x2])
print(grad)
# print(der_log_exp(x))
# Out:
# [<tf.Tensor: shape=(), dtype=float32, numpy=6.0>, <tf.Tensor: shape=(), dtype=float32, numpy=3.0>, None]
